# image 15/29 /content/License-Plate-1/test/images/c94k9fqfdhla1_jpg.rf.22be8494bd5fc986af43b0f088ab7613.jpg: 800x800 1 License, 17.6ms
# image 16/29 /content/License-Plate-1/test/images/cuwpuuf8gzoa1_jpg.rf.d0de19b8b1cb78d4dd72b97aba8d9dee.jpg: 800x800 1 License, 17.6ms
# image 17/29 /content/License-Plate-1/test/images/d2509e9522262c9a_jpg.rf.0cf230ee8a2a71e5c7a73246042999c9.jpg: 800x800 1 License, 12.7ms
# image 18/29 /content/License-Plate-1/test/images/dwlc3prqd9ga1_jpg.rf.c474ac1bc64fc6425ef05cdd957a2363.jpg: 800x800 1 License, 12.1ms
# image 19/29 /content/License-Plate-1/test/images/hoj7wt6bkxea1_jpg.rf.6d847a0feda50a9ee0be207dd1f8692d.jpg: 800x800 1 License, 12.0ms
# image 20/29 /content/License-Plate-1/test/images/l8uqlisis0fa1_jpg.rf.6386bbf91d55c5ee0004ab8253d4b45e.jpg: 800x800 1 License, 12.0ms
# image 21/29 /content/License-Plate-1/test/images/l8uqlisis0fa1_jpg.rf.a7b4c3c28901d896ca7369a973f78cf6.jpg: 800x800 1 License, 12.4ms
# image 22/29 /content/License-Plate-1/test/images/lemvtfhtxtoa1_jpg.rf.12ec176a42a7478c832cd48e694f2511.jpg: 800x800 2 Licenses, 12.8ms
# image 23/29 /content/License-Plate-1/test/images/lemvtfhtxtoa1_jpg.rf.248b814d466f7eef20ba1a7d5cc52634.jpg: 800x800 1 License, 12.8ms
# image 24/29 /content/License-Plate-1/test/images/lj9j7hpokbca1_jpg.rf.3431f4a755da47bd12c91e6035873f72.jpg: 800x800 1 License, 13.2ms
# image 25/29 /content/License-Plate-1/test/images/lsibmb1um6ea1_jpg.rf.41969df312d61ebed7a272aae142b1a2.jpg: 800x800 1 License, 13.4ms
# image 26/29 /content/License-Plate-1/test/images/luaw2gghbr9a1_jpg.rf.ca43b8aafc65f20ba5b0d452a70e0f59.jpg: 800x800 1 License, 13.5ms
# image 27/29 /content/License-Plate-1/test/images/m2qjy4ekz3ga1_jpg.rf.78dfac7fabec19b8a03a1eeb74e6fbaf.jpg: 800x800 1 License, 13.2ms
# image 28/29 /content/License-Plate-1/test/images/na0gapuzg0la1_jpg.rf.283a6198d9411637ad561370e899c277.jpg: 800x800 1 License, 12.9ms
# image 29/29 /content/License-Plate-1/test/images/ve3k2giaenna1_jpg.rf.7bb1346953f25ea8698313acccd156a7.jpg: 800x800 1 License, 12.2ms
# Speed: 3.9ms preprocess, 18.4ms inference, 6.5ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %%
# First, ensure easyocr is installed
# !pip install easyocr -q

# Import necessary libraries
import easyocr
from ultralytics import YOLO
from IPython.display import Image, display
import cv2
import os

# Define the path to the latest trained model
model_path = os.path.join(HOME, 'runs/detect/train/weights/best.pt')

# Check if the model file exists
if not os.path.exists(model_path):
    print(f"Error: Model file not found at {model_path}")
    print("Please ensure the training was successful and the path is correct.")
else:
    # Load the trained YOLOv8 model
    model = YOLO(model_path)

    # Initialize the OCR reader. This may download the model on the first run.
    reader = easyocr.Reader(['en'])

    # Define the path to a test image from your dataset
    test_image_path = os.path.join(dataset.location, 'test/images/Plate2_png.rf.e4ae7922324284ed2ed90fa4d0a374f7.jpg')

    print("--- Original Test Image ---")
    display(Image(filename=test_image_path, width=600))

    # Perform inference to detect license plates
    results = model(test_image_path)

    # Process the results
    for i, result in enumerate(results):
        # The result.boxes attribute contains the detected bounding boxes
        if len(result.boxes) == 0:
            print("No license plates detected in the image.")
            continue

        for j, box in enumerate(result.boxes):
            # Get bounding box coordinates in (left, top, right, bottom) format
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            # Crop the license plate from the original image
            license_plate_crop = result.orig_img[y1:y2, x1:x2]

            # Use easyocr to read text from the cropped license plate
            ocr_result = reader.readtext(license_plate_crop)

            print(f"\n--- Detected License Plate #{j+1} ---")
            # Convert crop to displayable format
            _, buffer = cv2.imencode('.jpg', license_plate_crop)
            display(Image(data=buffer.tobytes()))

            if ocr_result:
                print("\nRecognized Text:")
                for (bbox, text, prob) in ocr_result:
                    print(f"- '{text}' (Confidence: {prob:.2f})")
            else:
                print("\nOCR could not recognize any text on this license plate.")
# Out:
# --- Original Test Image ---
# image 1/1 /content/License-Plate-1/test/images/Plate2_png.rf.e4ae7922324284ed2ed90fa4d0a374f7.jpg: 416x800 2 Licenses, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 800)
#
# --- Detected License Plate #1 ---
# Recognized Text:
# - 'IND' (Confidence: 0.70)
# - 'HPO1 H50n1' (Confidence: 0.39)
#
# --- Detected License Plate #2 ---
# Recognized Text:
# - 'IND' (Confidence: 0.70)
# - 'HPO1 H 50' (Confidence: 0.77)

# %%
import easyocr
from ultralytics import YOLO
import cv2
import os

# Load the trained YOLOv8 model
model_path = os.path.join(HOME, 'runs/detect/train/weights/best.pt')

if not os.path.exists(model_path):
    print(f"Error: Model file not found at {model_path}")
else:
    model = YOLO(model_path)

    # Initialize the OCR reader
    reader = easyocr.Reader(['en'])

    # Path to the input video - PLEASE UPLOAD YOUR VIDEO AND CHANGE THIS PATH
    video_path = '/content/License-Plate-1/ANPR.mp4'
    output_video_path = '/content/License-Plate-1/processed_ANPR.mp4'

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video file {video_path}")
    else:
        # Get video properties
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))

        # Define the codec and create VideoWriter object
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # Perform inference
            results = model(frame)

            # Process the results
            for result in results:
                for box in result.boxes:
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    license_plate_crop = frame[y1:y2, x1:x2]

                    # Use easyocr to read text
                    ocr_result = reader.readtext(license_plate_crop)

                    # Draw bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

                    if ocr_result:
                        # Get the recognized text
                        text = " ".join([res[1] for res in ocr_result])
                        # Put the recognized text on the frame
                        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

            # Write the frame to the output video
            out.write(frame)

        # Release everything if job is finished
        cap.release()
        out.release()
        print(f"Processed video saved to {output_video_path}")
# Out:
# 0: 800x480 2 Licenses, 16.1ms
# Speed: 4.9ms preprocess, 16.1ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 13.8ms
# Speed: 6.6ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 9.7ms
# Speed: 5.5ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 9.7ms
# Speed: 4.9ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 9
ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 15.7ms
# Speed: 6.2ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 9.1ms
# Speed: 5.0ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 9.0ms
# Speed: 5.3ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 9.5ms
# Speed: 4.9ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 8.8ms
# Speed: 3.2ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 9.5ms
# Speed: 4.7ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 9.3ms
# ...
#
# 0: 800x480 1 License, 7.7ms
# Speed: 4.6ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.6ms
# Speed: 4.0ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.6ms
# Speed: 4.4ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.8ms
# Speed: 3.6ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 8.9ms
# Speed: 5.1ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.8ms
# Speed: 4.8ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.8ms
# Speed: 3.9ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 8.4ms
# Speed: 4.4ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.8ms
# Speed: 4.5ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 8.6ms
# Speed: 5.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 8.0ms
# Speed: 4.5ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 2 Licenses, 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 13.9ms
# Speed: 4.4ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 7.7ms
# Speed: 4.4ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License, 8.2ms
# Speed: 3.8ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.3ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.1ms
# Speed: 4.8ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.5ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.3ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 5.0ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.1ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.2ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.1ms
# Speed: 4.5ms preprocess, 8.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.2ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.7ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.1ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 5.2ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.3ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.0ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.1ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.4ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.4ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.5ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 3.9ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.1ms
# Speed: 4.4ms preprocess, 13.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.7ms
# Speed: 4.9ms preprocess, 8.7ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.6ms
# Speed: 5.6ms preprocess, 13.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 10.6ms
# Speed: 5.4ms preprocess, 10.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 5.8ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.2ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.4ms
# Speed: 4.8ms preprocess, 8.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.1ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.1ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.3ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.9ms
# Speed: 4.3ms preprocess, 7.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.5ms
# Speed: 4.7ms preprocess, 8.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.2ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 4.4ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 3.9ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.2ms
# Speed: 4.3ms preprocess, 8.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.3ms
# Speed: 4.8ms preprocess, 8.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.2ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.4ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.5ms
# Speed: 4.3ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.6ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.3ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.5ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.8ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.7ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.6ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 4.0ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.7ms
# Speed: 3.9ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 7.8ms
# Speed: 4.6ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.1ms
# Speed: 5.0ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 4.1ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 3.7ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 4.0ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 4.4ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.8ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.6ms
# Speed: 4.3ms preprocess, 8.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.6ms
# Speed: 4.6ms preprocess, 8.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 5.3ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 4.7ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.3ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.7ms
# Speed: 4.4ms preprocess, 8.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.7ms
# Speed: 5.0ms preprocess, 8.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.6ms
# Speed: 3.8ms preprocess, 8.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.6ms
# Speed: 4.2ms preprocess, 8.6ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 4.4ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 3.9ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.2ms
# Speed: 5.2ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 4.2ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.7ms
# Speed: 4.4ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.3ms
# Speed: 4.3ms preprocess, 9.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.7ms
# Speed: 4.3ms preprocess, 8.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 4.7ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 4.4ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 3.9ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 4.1ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.5ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 4.3ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.5ms
# Speed: 4.3ms preprocess, 9.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.8ms
# Speed: 5.1ms preprocess, 8.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 4.2ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.2ms
# Speed: 4.2ms preprocess, 9.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.1ms
# Speed: 3.8ms preprocess, 9.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.1ms
# Speed: 4.3ms preprocess, 9.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.1ms
# Speed: 4.3ms preprocess, 9.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.3ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 3.9ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.9ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.3ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.1ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 5.3ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.5ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.4ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 3.9ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 9.0ms
# Speed: 6.3ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 8.9ms
# Speed: 4.5ms preprocess, 8.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 480)
# Processed video saved to //content/License-Plate-1/processed_ANPR.mp4
